# %%
# %pylab inline
from pylab import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
x=linspace(0,10,100)
y=tanh(x)

# %%
figure()
plot(x, y, 'r')
xlabel('External Magnetic Field')
ylabel('M')
title('Tanh theory')
show();
